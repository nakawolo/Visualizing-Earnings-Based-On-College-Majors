# %% [markdown]
# # Visualizing Earnings Based On College Majors ##
#
# In this guided project from dataquest.io i'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by American Community Survey, which conducts surveys and aggregates the data. FiveThirtyEight (FiveThirtyEight is an American news website specializing in statistics and data journalism) cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).
#
# I want to explore questions from the dataset like:
# * Do students in more popular majors make more money?
# * How many majors are predominantly male? Predominantly female?
# * Which category of majors have the most students?
#
# ### Summary of results
#
# For more details, please refer to the the full analysis below.
#
# # Describing the data
#
# Each row in the dataset "recent-grads.csv" represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# * Rank - Rank by median earnings (the dataset is ordered by this column).
# * Major_code - Major code.
# * Major - Major description.
# * Major_category - Category of major.
# * Total - Total number of people with major.
# * Sample_size - Sample size (unweighted) of full-time.
# * Men - Male graduates.
# * Women - Female graduates.
# * ShareWomen - Women as share of total.
# * Employed - Number employed.
# * Median - Median salary of full-time, year-round workers.
# * Low_wage_jobs - Number in low-wage service jobs.
# * Full_time - Number employed 35 hours or more.
# * Part_time - Number employed less than 35 hours.

# %%
# Import libraries and remove rows containing null values.
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads = recent_grads.dropna()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# # Creating Scatter Plots

# %%
plt.style.use('fivethirtyeight')
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
# Out:
# 36000.0

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
# Out:
# 0.06754447999999999

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# # Creating Histograms

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,30))
for r in range(1,5):
    ax = fig.add_subplot(4,1,r)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)
    ax.set_xlabel(cols[r])

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,30))
for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)
    ax.set_xlabel(cols[r])

# %% [markdown]
# # Creating a Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121896278>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121bd5780>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12187fd30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121e7edd8>]], dtype=object)

# %% [markdown]
# # Creating Bar Plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)
